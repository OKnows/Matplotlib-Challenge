# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
#all_data = pd.merge()a
all_data=pd.merge(mouse_metadata, study_results, how="left", on=["Mouse ID"])

# Display the data table for preview
all_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
total_mice = all_data["Mouse ID"].nunique()
total_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice_timepoint = all_data.loc[all_data.duplicated(subset=["Mouse ID", "Timepoint"]),"Mouse ID"].unique()
duplicate_mice_timepoint
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mice = all_data.loc[all_data["Mouse ID"] == "g989", :]
duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_df = all_data[all_data["Mouse ID"].isin(duplicate_mice)==False]
cleaned_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
deduped_mice = cleaned_df["Mouse ID"].nunique()
deduped_mice
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
cleaned_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for 
#each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
mean = cleaned_df["Tumor Volume (mm3)"].groupby(cleaned_df["Drug Regimen"]).mean()
median = cleaned_df["Tumor Volume (mm3)"].groupby(cleaned_df["Drug Regimen"]).median()
variance = cleaned_df["Tumor Volume (mm3)"].groupby(cleaned_df["Drug Regimen"]).var()
standard_deviation = cleaned_df["Tumor Volume (mm3)"].groupby(cleaned_df["Drug Regimen"]).std()
sem = cleaned_df["Tumor Volume (mm3)"].groupby(cleaned_df["Drug Regimen"]).sem()

# Assemble the resulting series into a single summary DataFrame.
dataframe = pd.DataFrame({"Mean Tumor Volume": mean, "Median Tumor Volume": median, "Tumor Volume Variance": variance, 
                           "Tumor Volume Std. Dev.": standard_deviation, "Tumor Volume Std. Err.": sem})
summary_df = round(dataframe, 2)
summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin                 40.68                41.56                  24.95
# Ceftamin                  52.59                51.78                  39.29
# Infubinol                 52.88                51.82                  43.13
# Ketapril                  55.24                53.70                  68.55
# Naftisol                  54.33                52.51                  66.17
# Placebo                   54.03                52.29                  61.17
# Propriva                  52.32                50.85                  42.35
# Ramicane                  40.22                40.67                  23.49
# Stelasyn                  54.23                52.43                  59.45
# Zoniferol                 53.24                51.82                  48.53
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line.

summary_stats = cleaned_df.groupby(["Drug Regimen"])[["Tumor Volume (mm3)"]].agg(["mean", "median", "var", "std", "sem"])
summary_stats_df = pd.DataFrame(summary_stats)
summary_stats_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

timepoints_df = cleaned_df.groupby(["Drug Regimen"])[["Timepoint"]].count()
timepoints_df.plot(kind = "bar", 
                  ylabel = "Number of mice tested")
plt.tight_layout()

# %%
timepoints_df
# Out:
#               Timepoint
# Drug Regimen
# Capomulin           230
# Ceftamin            178
# Infubinol           178
# Ketapril            188
# Naftisol            186
# Placebo             181
# Propriva            161
# Ramicane            228
# Stelasyn            181
# Zoniferol           182

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
plt.bar(timepoints_df.index.values, timepoints_df["Timepoint"])
plt.xticks(rotation=90)
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.show()

# %%
cleaned_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_count = cleaned_df["Sex"].value_counts()
mouse_gender = gender_count.plot(kind="pie", y = "Sex", title = "Female vs. Male Mice", autopct= "%1.0f%%")
mouse_gender.set_ylabel("Sex")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender = cleaned_df["Sex"].value_counts()
labels = ["Male", "Female"]
plt.pie(gender, labels = labels, autopct = "%1.0f%%")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
#for reference
cleaned_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
capomulin_df = cleaned_df.loc[cleaned_df["Drug Regimen"]=="Capomulin", :]
ramicane_df = cleaned_df.loc[cleaned_df["Drug Regimen"]=="Ramicane", :]
infubinol_df=cleaned_df.loc[cleaned_df["Drug Regimen"]=="Infubinol", :]
ceftamin_df=cleaned_df.loc[cleaned_df["Drug Regimen"]=="Ceftamin", :]

# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

#capomulin
capomulin_max = capomulin_df.groupby("Mouse ID")["Timepoint"].max()
capomulin_merge = pd.merge(capomulin_max, cleaned_df, on=["Mouse ID", "Timepoint"], how="left")

#--------------------------------------------------------------------------------------------------
#ramicane
ramicane_max = ramicane_df.groupby("Mouse ID")["Timepoint"].max()
ramicane_merge = pd.merge(ramicane_max, cleaned_df, on=["Mouse ID", "Timepoint"], how="left")

#--------------------------------------------------------------------------------------------------
#infubinol
infubinol_max = infubinol_df.groupby("Mouse ID")["Timepoint"].max()
infubinol_merge = pd.merge(infubinol_max, cleaned_df, on=["Mouse ID", "Timepoint"], how="left")

#--------------------------------------------------------------------------------------------------
#ceftamin
ceftamin_max = ceftamin_df.groupby("Mouse ID")["Timepoint"].max()
ceftamin_merge = pd.merge(ceftamin_max, cleaned_df, on=["Mouse ID", "Timepoint"], how="left")

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments=['capomulin', 'ramicane', 'infubinol', 'ceftamin']

# Create list to fill with tumor vol data (for plotting)
capomulin_tumors = capomulin_merge["Tumor Volume (mm3)"]
ramicane_tumors = capomulin_merge["Tumor Volume (mm3)"]
infubinol_tumors = infubinol_merge["Tumor Volume (mm3)"]
ceftamin_tumors = ceftamin_merge["Tumor Volume (mm3)"]

    
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
#capomulin
capomulin_quantiles = capomulin_tumors.quantile([0.25, 0.5, 0.75])
capomulin_upperq = capomulin_quantiles[.75]
capomulin_lowerq = capomulin_quantiles[.25]
capomulin_iqr = capomulin_upperq - capomulin_lowerq
#ramicane
ramicane_quantiles = ramicane_tumors.quantile([0.25, 0.5, 0.75])
ramicane_upperq = ramicane_quantiles[.75]
ramicane_lowerq = ramicane_quantiles[.25]
ramicane_iqr = ramicane_upperq - ramicane_lowerq
#infubinol
infubinol_quantiles = infubinol_tumors.quantile([0.25, 0.5, 0.75])
infubinol_upperq = infubinol_quantiles[.75]
infubinol_lowerq = infubinol_quantiles[.25]
infubinol_iqr = infubinol_upperq - infubinol_lowerq
#ceftamin
ceftamin_quantiles = ceftamin_tumors.quantile([0.25, 0.5, 0.75])
ceftamin_upperq = ceftamin_quantiles[.75]
ceftamin_lowerq = ceftamin_quantiles[.25]
ceftamin_iqr = ceftamin_upperq - ceftamin_lowerq

# Determine outliers using upper and lower bounds
#capomulin
cap_lower_bound = round((capomulin_lowerq - 1.5 * capomulin_iqr), 2)
cap_upper_bound = round((capomulin_upperq + 1.5 * capomulin_iqr), 2)
print(f"For Capomulin, values below {cap_lower_bound} could be outliers.")
print(f"For Capomulin, values below {cap_upper_bound} could be outliers.")
print("---------------------------------------------------------")
#ramicane
ram_lower_bound = round((ramicane_lowerq - 1.5 * ramicane_iqr), 2)
ram_upper_bound = round((ramicane_upperq + 1.5 * ramicane_iqr), 2)
print(f"For Ramicane, values below {ram_lower_bound} could be outliers.")
print(f"For Ramicane, values below {ram_upper_bound} could be outliers.")
print("---------------------------------------------------------")
#infubinol
infub_lower_bound = round((infubinol_lowerq - 1.5 * infubinol_iqr), 2)
infub_upper_bound = round((infubinol_upperq + 1.5 * infubinol_iqr), 2)
print(f"For Infubinol, values below {infub_lower_bound} could be outliers.")
print(f"For Infubinol, values below {infub_upper_bound} could be outliers.")
print("---------------------------------------------------------")
#ceftamin
ceft_lower_bound = round((ceftamin_lowerq - 1.5 * ceftamin_iqr), 2)
ceft_upper_bound = round((ceftamin_upperq + 1.5 * ceftamin_iqr), 2)
print(f"For Ceftamin, values below {infub_lower_bound} could be outliers.")
print(f"For Ceftamin, values below {infub_upper_bound} could be outliers.")
print("---------------------------------------------------------")
# Out:
# For Capomulin, values below 20.7 could be outliers.
# For Capomulin, values below 51.83 could be outliers.
# ---------------------------------------------------------
# For Ramicane, values below 20.7 could be outliers.
# For Ramicane, values below 51.83 could be outliers.
# ---------------------------------------------------------
# For Infubinol, values below 36.83 could be outliers.
# For Infubinol, values below 82.74 could be outliers.
# ---------------------------------------------------------
# For Ceftamin, values below 36.83 could be outliers.
# For Ceftamin, values below 82.74 could be outliers.
# ---------------------------------------------------------

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

boxplot=[capomulin_tumors, ramicane_tumors, infubinol_tumors, ceftamin_tumors]
fig = plt.figure()
plt.xlabel("Regimen")
plt.ylabel("Tumor Volume")
plt.title("Tumor Volume by Drug Regimen")
plt.boxplot(boxplot)
plt.xticks([1,2,3,4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
#for reference 
capomulin_df.head()
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouse_line = capomulin_df.loc[capomulin_df['Mouse ID']=='s185', :]
x_axis=mouse_line['Tumor Volume (mm3)']
y_axis=mouse_line['Timepoint']
plt.plot(x_axis, y_axis)
plt.title('Mouse s185 tumor volume vs timepoint on Capomulin')
plt.xlabel('Tumor Volume(mm3)')
plt.ylabel('Timepoint')
plt.show()

# %%
#for reference 
capomulin_df.head()
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
fig1, ax1 = plt.subplots()
avg_capm_vol =capomulin_df.groupby(['Mouse ID']).mean()
marker_size=15
plt.scatter(avg_capm_vol['Weight (g)'],avg_capm_vol['Tumor Volume (mm3)'], color="red")
plt.title('Mouse Weight vds Average Tumor Volume')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

correlation = st.pearsonr(avg_capm_vol['Weight (g)'],avg_capm_vol['Tumor Volume (mm3)'])
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84

# %%
(slope, intercept,rvalue, pvalue, stderr)= linregress(avg_capm_vol["Weight (g)"],avg_capm_vol["Tumor Volume (mm3)"])
regress_values=avg_capm_vol["Weight (g)"]* slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"

plt.scatter(avg_capm_vol["Weight (g)"],avg_capm_vol["Tumor Volume (mm3)"],color='b')
plt.plot(avg_capm_vol["Weight (g)"], regress_values, color='red')
plt.annotate(line_eq,(20,36), fontsize=14)
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Weight vs Tumor Volume for Capomulin")
print(f"The r-squared is: {round(rvalue**2,3)}")
plt.show()
# Out:
# The r-squared is: 0.709
